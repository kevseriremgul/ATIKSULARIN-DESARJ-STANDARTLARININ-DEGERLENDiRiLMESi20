# %%
x=input("Bir sanayi adı giriniz:")
if x=="Gıda Sanayi":
  AKM=int(input("AKM değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  Renk=int(input("Renk değeri giriniz:"))
  ÇKM=float(input("Çökebilir katı madde değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  KOI=int(input("KOİ değeri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  PO4=int(input("Fosfat fosforu değeri giriniz:"))
  ei=int(input("Elektriksel iletkenlik değeri giriniz:"))

  if KOI<=160 and AKM<=120 and 6<=pH<=9 and YVG<=60 and Renk<=280 and ÇKM<=0.5 and ZSF<=4 and NH4<=20 and PO4<=3 and ei<=20000:
   print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOI>160:
   print("Koi değeri standartlara uygun değil")
  if AKM>120:
   print("AKM değeri standartlara uygun değil")
  if pH<6 and pH>=9:
   print("pH değeri standartlara uygun değil")
  if YVG>60:
   print("Yağ ve Gres değeri standartlara uygun değil")
  if Renk>280:
   print("Renk değeri standartlara uygun değil")
  if ÇKM>0.5:
   print("Çökebilir katı madde değeri standartlara uygun değil")
  if ZSF>4:
   print("ZSF değeri standartlara uygun değil")
  if NH4>20:
    print("Amonyum azotu değeri standartlara uygun değil")
  if PO4>3:
    print("Fosfat fosforu değeri standartlara uygun değil")
  if ei>20000:
    print("Elektriksel iletkenlik değeri standartlara uygun değil")

if x=="İçki Sanayi":
  KOI=int(input("KOİ değeri giriniz:"))
  Renk=int(input("Renk değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  ÇKM=float(input("Çökebilir katı madde değeri giriniz:"))

  if KOI<=200 and Renk<=280 and 6<=pH<=9 and ÇKM<=0.3:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOI>200:
   print("Koi değeri standartlara uygun değil")
  if pH<6 and pH>=9:
   print("pH değeri standartlara uygun değil")
  if Renk>280:
   print("Renk değeri standartlara uygun değil")
  if ÇKM>0.3:
   print("Çökebilir katı madde değeri standartlara uygun değil")

if x=="Maden Sanayi":
  KOI=int(input("KOİ değeri giriniz:"))
  AKM=int(input("AKM değeri giriniz:"))
  TCN=float(input("Toplam Siyanür değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  SO4=int(input("Sülfat değeri giriniz:"))
  Hg=float(input("Cıva değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Cu=int(input("Bakır değeri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  B=int(input("Bor değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  Cr=float(input("Krom değerleri giriniz:"))
  Pb=float(input("Kurşun değeri giriniz:"))

  if KOI<=90 and AKM<=100 and Pb<=0.5 and TCN<=0.1 and Fe<=3 and Zn<=3 and SO4<=1500 and Hg<=0.05 and Cd<=0.2 and Cu<=5 and TCr<=2 and 6<=pH<=9 and ZSF<=4 and renk<=280 and B<=500 and YVG<=10 and Cr<=0.3:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOI>90:
   print("Koi değeri standartlara uygun değil")
  if AKM>100:
   print("AKM değeri standartlara uygun değil")
  if Pb>0.5:
   print("Kurşun değeri standartlara uygun değil")
  if TCN>0.1:
   print("Toplam Siyanür değeri standartlara uygun değil")
  if Fe>3:
   print("Demir değeri standartlara uygun değil")
  if Zn>3:
   print("Çinko değeri standartlara uygun değil")
  if SO4>1500:
   print("Sülfat değeri standartlara uygun değil")
  if Hg>0.05:
   print("Cıva değeri standartlara uygun değil")
  if Cd>0.2:
   print("Kadmiyum değeri standartlara uygun değil")
  if Cu>5:
   print("Bakır değeri standartlara uygun değil")
  if TCr>2:
   print("Toplam Krom değeri standartlara uygun değil")
  if pH<6 and pH>=9:
   print("pH değeri standartlara uygun değil")
  if ZSF>4:
   print("ZSF değeri standartlara uygun değil")
  if renk>280:
   print("Renk değeri standartlara uygun değil")
  if B>500:
   print("Bor değeri standartlara uygun değil")
  if YVG>10:
   print("Yağ ve Gres değeri standartlara uygun değil")
  if Cr>0.3:
   print("Krom değeri standartlara uygun değil")

if x=="Cam Sanayi":
  KOI=int(input("KOİ değeri giriniz:"))
  Florür=int(input("Florür değeri giriniz:"))
  Ni=int(input("Nikel değeri giriniz:"))
  Ag=int(input("Gümüş değeri giriniz:"))
  Pb=int(input("Kurşun değeri giriniz:"))
  SO4=int(input("Sülfat değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))

  if KOI<=220 and Florür<=30 and Ni<=3 and Ag<=1 and Pb<=1 and SO4<=3000 and 6<=pH<=9:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOI>220:
   print("Koi değeri standartlara uygun değil")
  if Florür>30:
   print("Florür değeri standartlara uygun değil")
  if Ni>3:
   print("Nikel değeri standartlara uygun değil")
  if Ag>1:
   print("Gümüş değeri standartlara uygun değil")
  if Pb>1:
   print("Kurşun değeri standartlara uygun değil")
  if SO4>3000:
   print("Sülfat değeri standartlara uygun değil")
  if pH<6 and pH>9:
   print("pH değeri standartlara uygun değil")

if x=="Kömür Sanayi":
  KOI=int(input("KOİ değeri giriniz:"))
  AKM=int(input("AKM değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  TCN=float(input("Toplam Siyanür değeri giriniz:"))
  T=int(input("Sıcaklık değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  Fenol=int(input("Fenol değeri giriniz:"))
  P=int(input("Toplam Fosfor değeri giriniz:"))
  SCl=float(input("Serbest Klor değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  ÇKM=float(input("Çökebilir katı madde değeri giriniz:"))
  N2H4=int(input("Hidrazin değeri giriniz:"))
  V=int(input("Vanadyum değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))

  if KOI<=100 and AKM<=150 and YVG<=20 and TCN<=0.5 and T<=35 and 6<=pH<=9 and Fenol<=1 and P<=8 and SCl<=0.3 and Zn<=4 and ÇKM<=0.3 and N2H4<=5 and V<=3 and Fe<=7:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOI>100:
   print("Koi değeri standartlara uygun değil")
  if AKM>150:
   print("AKM değeri standartlara uygun değil")
  if YVG>20:
   print("Yağ ve Gres değeri standartlara uygun değil")
  if TCN>0.5:
   print("Toplam Siyanür değeri standartlara uygun değil")
  if T>35:
   print("Sıcaklık değeri standartlara uygun değil")
  if pH<6 and pH>9:
   print("pH değeri standartlara uygun değil")
  if Fenol>1:
   print("Fenol değeri standartlara uygun değil")
  if P>8:
   print("Toplam Fosfor değeri standartlara uygun değil")
  if SCl>0.3:
   print("Serbest Klor değeri standartlara uygun değil")
  if Zn>4:
   print("Çinko değeri standartlara uygun değil")
  if ÇKM>0.3:
   print("Çökebilir katı madde değeri standartlara uygun değil")
  if N2H4>5:
   print("Hidrazin değeri standartlara uygun değil")
  if V>3:
   print("Vanadyum değeri standartlara uygun değil")
  if Fe>7:
   print("Demir değeri standartlara uygun değil")

if x=="Tekstil Sanayi":
  KOI=int(input("KOİ değeri giriniz:"))
  SCl=float(input("Serbest Klor değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  AKM=int(input("AKM değeri giriniz:"))
  Fenol=int(input("Fenol değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  Sülfür=float(input("Sülfür değeri giriniz:"))
  Sülfit=int(input("Sülfit değeri giriniz:"))

  if KOI<=250 and SCl<=0.3 and YVG<=10 and ZSF<=4 and 6<=pH<=9 and renk<=280 and AKM<=140 and Fenol<=1 and Zn<=12 and NH4<=5 and TCr<=2 and Sülfür<=0.1 and Sülfit<=1:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOI>250:
   print("Koi değeri standartlara uygun değil")
  if SCl>0.3:
   print("Serbest Klor değeri standartlara uygun değil")
  if YVG>10:
   print("Yağ ve Gres değeri standartlara uygun değil")
  if ZSF>4:
   print("ZSF değeri standartlara uygun değil")
  if pH<6 and pH>9:
   print("pH değeri standartlara uygun değil")
  if renk>280:
   print("Renk değeri standartlara uygun değil")
  if AKM>140:
   print("AKM değeri standartlara uygun değil")
  if Fenol>1:
   print("Fenol değeri standartlara uygun değil")
  if Zn>12:
   print("Çinko değeri standartlara uygun değil")
  if NH4>5:
   print("Amonyum Azotu değeri standartlara uygun değil")
  if TCr>2:
   print("Toplam Krom değeri standartlara uygun değil")
  if Sülfür>0.1:
   print("Sülfür değeri standartlara uygun değil")
  if Sülfit>1:
   print("Sülfit değeri standartlara uygun değil")

if x=="Petrol Sanayi":
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  akm=int(input("AKM değeri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  Fenol=int(input("Fenol değeri giriniz:"))
  Sülfür=int(input("Sülfür değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  koi=int(input("KOİ değeri giriniz:"))
  SCl=float(input("Serbest Klor değeri giriniz:"))
  SO4=int(input("Sülfat değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Fenoller=int(input("Fenoller değeri giriniz:"))
  Hg=float(input("Cıva değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  Pb=int(input("Kurşun değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Cu=int(input("Bakır değeri giriniz:"))
  TCN=int(input("Toplam Siyanür değeri giriniz:"))
  HC=int(input("Hidrokarbonlar değeri giriniz:"))
  Cr=float(input("krom değeri giriniz:"))
  Na=int(input("Sodyum değeri giriniz:"))

  if koi<=250 and SCl<=0.3 and YVG<=20 and ZSF<=6 and 6<=pH<=9 and renk<=280 and akm<=120 and Fenol<=2 and Zn<=1 and NH4<=40 and Sülfür<=2 and Cr<=0.2 and TCN<=2 and HC<=15 and Na<=250 and SO4<=2000 and Fe<=10 and Fenoller<=2 and Hg<=0.05 and Cd<=0.15 and Cu<=1 and Pb<=1:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if koi>250:
   print("Koi değeri standartlara uygun değil")
  if SCl>0.3:
   print("Serbest Klor değeri standartlara uygun değil")
  if YVG>20:
   print("Yağ ve Gres değeri standartlara uygun değil")
  if ZSF>6:
   print("ZSF değeri standartlara uygun değil")
  if pH<6 and pH>9:
   print("pH değeri standartlara uygun değil")
  if renk>280:
   print("Renk değeri standartlara uygun değil")
  if akm>120:
   print("AKM değeri standartlara uygun değil")
  if Fenol>2:
   print("Fenol değeri standartlara uygun değil")
  if Zn>1:
   print("Çinko değeri standartlara uygun değil")
  if NH4>40:
   print("Amonyum Azotu değeri standartlara uygun değil")
  if Sülfür>2:
   print("Sülfür değeri standartlara uygun değil")
  if Cr>0.2:
   print("Krom değeri standartlara uygun değil")
  if TCN>2:
   print("Toplam Siyanür değeri standartlara uygun değil")
  if HC>15:
   print("Hidrokarbonlar değeri standartlara uygun değil")
  if Na>250:
   print("Sodyum değeri standartlara uygun değil")
  if SO4>2000:
   print("Sülfat değeri standartlara uygun değil")
  if Fe>10:
   print("Demir değeri standartlara uygun değil")
  if Fenoller>2:
   print("Fenoller değeri standartlara uygun değil")
  if Hg>0.05:
   print("Cıva değeri standartlara uygun değil")
  if Cd>0.15:
   print("Kadmiyum değeri standartlara uygun değil")
  if Cu>1:
   print("Bakır değeri standartlara uygun değil")
  if Pb>1:
   print("Kurşun değeri standartlara uygun değil")

if x=="Selüloz Sanayi":
  akm=int(input("AKM değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  koi=int(input("KOİ değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))

  if koi<=500 and 6<=pH<=9 and renk<=280 and ZSF<=10 and akm<=150:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if koi>500:
   print("Koi değeri standartlara uygun değil")
  if ZSF>10:
   print("ZSF değeri standartlara uygun değil")
  if pH<6 and pH>9:
   print("pH değeri standartlara uygun değil")
  if renk>280:
   print("Renk değeri standartlara uygun değil")
  if akm>150:
   print("AKM değeri standartlara uygun değil")

if x=="Kimya Sanayi":
  koi=int(input("KOİ değeri giriniz:"))
  akm=int(input("AKM değeri giriniz:"))
  YVG=int(input("Yağ ve gres değeri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  ACl=int(input("Aktif Klor değeri giriniz:"))
  Sülfür=int(input("Sülfür değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  SCl=int(input("Serbest Klor değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Fenoller=float(input("Fenoller değeri giriniz:"))
  Hg=float(input("Civa değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  Pb=int(input("Kurşun değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Cu=int(input("Bakır değeri giriniz:"))
  TCN=int(input("Toplam Siyanür değeri giriniz:"))
  HC=int(input("Hidrokarbonlar değeri giriniz:"))
  Cr=float(input("krom değeri giriniz:"))
  NO3=int(input("Nitrat Azotu değeri giriniz:"))
  B=int(input("Bor değeri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  TCd=float(input("Toplam Kadmiyum değeri giriniz:"))
  Florür=int(input("Florür değeri giriniz:"))
  PO4=int(input("Fosfat Fosforu değeri giriniz:"))
  MBAS=int(input("Yüzey aktif madde değeri giriniz:"))
  Cl=int(input("Klorür değeri giriniz:"))
  ÇKM=float(input("Çökebilir katı madde değeri giriniz:"))
  SCN=float(input("Serbest Siyanür değeri giriniz:"))
  Ba=int(input("Baryum değeri giriniz:"))
  TKN=int(input("Toplam kjeldahl Azotu değeri giriniz:"))
  TP=int(input("Toplam fosfor değeri giriniz:"))

  if koi<=70 and akm<= 60 and SCl<=4 and ACl<=5 and YVG<=20 and ZSF<=5 and 6<=pH<=9 and renk<=280 and Zn<=4 and NH4<=50 and Sülfür<=2 and Cr<=0.5 and TCN<=2 and HC<=15 and Fe<=30 and Fenoller<=2 and Hg<=0.05 and Cd<=0.2 and Cu<=1 and Pb<=1 and TKN<=15 and Cl<=15000 and SCN<=0.5 and TCd<=0.5 and ÇKM<=0.3 and Ba<=5 and MBAS<=10 and PO4<=35 and Florür<=15 and TCr<=2 and B<=500 and NO3<=50 and TP<=2:
    print("Deşarj Standartlarına uygun")
  else:
    print("Deşarj Standartlarına uygun değil çünkü;")
  if koi>70:
    print("Koi değeri standartlara uygun değil")
  if akm>60:
    print("AKM değeri standartlara uygun değil")
  if ACl>5:
    print("Aktif klor değeri standartlara uygun değil")
  if SCl>4:
    print("Serbest Klor değeri standartlara uygun değil")
  if YVG>20:
    print("Yağ ve Gres değeri standartlara uygun değil")
  if ZSF>5:
    print("ZSF değeri standartlara uygun değil")
  if pH<6 and pH>9:
    print("pH değeri standartlara uygun değil")
  if renk>280:
    print("Renk değeri standartlara uygun değil")
  if Zn>4:
    print("Çinko değeri standartlara uygun değil")
  if NH4>50:
    print("Amonyum Azotu değeri standartlara uygun değil")
  if Sülfür>2:
    print("Sülfür değeri standartlara uygun değil")
  if Cr>0.5:
    print("Krom değeri standartlara uygun değil")
  if TCN>2:
    print("Toplam Siyanür değeri standartlara uygun değil")
  if HC>15:
    print("Hidrokarbonlar değeri standartlara uygun değil")
  if Fe>30:
    print("Demir değeri standartlara uygun değil")
  if Fenoller>2:
    print("Fenoller değeri standartlara uygun değil")
  if Hg>0.05:
    print("Civa değeri standartlara uygun değil")
  if Cd>0.2:
    print("Kadminyum değeri standartlara uygun değil")
  if Cu>1:
    print("Bakır değeri standartlara uygun değil")
  if Pb>1:
    print("Kurşun değeri standartlara uygun değil")
  if TKN>15:
    print("Toplam kjeldahl Azotu değeri standartlara uygun değil")
  if Cl>15000:
    print("Klor değeri standartlara uygun değil")
  if SCN>0.5:
    print("Serbest Siyanür değeri standartlara uygun değil")
  if TCd>0.5:
    print("Toplam Kadminyum değeri standartlara uygun değil")
  if ÇKM>0.3:
    print("Çökebilen katı madde değeri standartlara uygun değil")
  if Ba>5:
    print("Baryum değeri standartlara uygun değil")
  if MBAS>10:
    print("Yüzey Aktif madde değeri standartlara uygun değil")
  if PO4>35:
    print("Fosfat fosforu değeri standartlara uygun değil")
  if Florür>15:
    print("Florür değeri standartlara uygun değil")
  if TCr>2:
    print("Toplam Krom değeri standartlara uygun değil")
  if B>500:
    print("Bor değeri standartlara uygun değil")
  if NO3>50:
    print("Nitrat azotu değeri standartlara uygun değil")
  if TP>2:
    print("Toplam fosfor değeri standartlara uygun değil")

if x=="Metal Sanayi":
  koi=int(input("KOİ değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  ÇKM=float(input("Çökebilir katı madde değeri giriniz:"))
  Pb=float(input("Kurşun değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  akm=int(input("AKM değeri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  NO2=int(input("Nitrit Azotu değeri giriniz:"))
  ACl=float(input("Aktif Klor değeri giriniz:"))
  Sülfür=int(input("Sülfür değeri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  Cr=float(input("Krom değeri giriniz:"))
  TCN=float(input("Toplam Siyanür değeri giriniz:"))
  Hg=float(input("Civa değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Al=int(input("Alüminyum değeri giriniz:"))
  Florür=int(input("Florür değeri giriniz:"))
  Cu=int(input("Bakır değeri giriniz:"))
  Ni=int(input("Nikel değeri giriniz:"))
  Ag=float(input("Gümüş değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  As=float(input("Arsenik değeri giriniz:"))

  if koi<=90 and YVG<=20 and ÇKM<=0.5 and Pb<=0.5 and Fe<=20 and Zn<=4 and 6<=pH<=9 and akm<=120 and NH4<=100 and NO2<=10 and ACl<=0.5 and Sülfür<=2 and TCr<=2 and Cr<=0.5 and TCN<=0.5 and Hg<=0.05 and Cd<=0.5 and Al<=3 and Florür<=50 and Cu<=3 and Ni<=3 and Ag<=0.1 and ZSF<=10 and As<=0.1:
    print("Deşarj Standartlarına Uygun")
  else:
    print("Deşarj Standartlarına Uygun Değil Çünkü;")
  if koi>90:
    print("Koi değeri standartlara uygun değil")
  if YVG>20:
    print("Yağ ve Gres değeri standartlara uygun değil")
  if ÇKM>0.5:
    print("Çökebilir katı madde değeri standartlara uygun değil")
  if Pb>0.5:
    print("Kurşun değeri standartlara uygun değil")
  if Fe>20:
    print("Demir değeri standartlara uygun değil")
  if Zn>4:
    print("Çinko değeri standartlara uygun değil")
  if pH<6 and ph>9:
    print("pH değeri standartlara uygun değil")
  if akm>120:
    print("AKM değeri standartlara uygun değil")
  if NH4>100:
    print("Amonyum Azotu değeri standartlara uygun değil")
  if NO2>10:
    print("Nitrit Azotu değeri standartlara uygun değil")
  if ACl>0.5:
    print("Aktif Klor değeri standartlara uygun değil")
  if Sülfür>2:
    print("Sülfür değeri standartlara uygun değil")
  if TCr>2:
    print("Toplam Krom değeri standartlara uygun değil")
  if Cr>0.5:
    print("Krom değeri standartlara uygun değil")
  if TCN>0.5:
    print("Toplam siyanür değeri standartlara uygun değil")
  if Hg>0.05:
    print("Civa değeri standartlara uygun değil")
  if Cd>0.5:
    print("Kadmiyum değeri standartlara uygun değil")
  if Al>3:
    print("Alüminyum değeri standartlara uygun değil")
  if Florür>50:
    print("Florür değeri standartlara uygun değil")
  if Cu>3:
    print("Bakır değeri standartlara uygun değil")
  if Ni>3:
    print("Nikel değeri standartlara uygun değil")
  if Ag>0.1:
    print("Gümüş değeri standartlara uygun değil")
  if ZSF>10:
    print("ZSF değeri standartlara uygun değil")
  if As>0.1:
    print("Arsenik değeri standartlara uygun değil")

if x=="Ağaç Mamulleri ve Mobilya Sanayi":
  koi=int(input("KOİ değeri giriniz:"))
  ÇKM=float(input("Çökebilir katı madde değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))

  if koi<=90 and ÇKM<=0.5 and 6<=pH<=9:
    print("Deşarj Standartlarına Uygun")
  else:
    print("Deşarj Standartlarına Uygun Değil Çünkü;")
  if koi>90:
    print("Koi değeri standartlara uygun değil")
  if ÇKM>0.5:
    print("Çökebilir katı madde değeri standartlara uygun değil")
  if pH<6 and pH>9:
    print("pH değeri standartlara uygun değil")

if x=="Seri Makine imalatı Sanayi":
  koi=int(input("KOİ değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  Cr=float(input("Krom değeri giriniz:"))
  Pb=int(input("Kurşun değeri giriniz:"))
  TCN=float(input("Toplam Siyanür değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))

  if koi<=150 and YVG<=20 and NH4<=150 and Cr<=0.5 and Pb<=2 and TCN<=0.5 and 6<pH<9:
    print("Deşarj Standartlarına Uygun")
  else:
    print("Deşarj Standartlarına Uygun Değil Çünkü;")
  if koi>150:
    print("Koi değeri standartlara uygun değil")
  if YVG>20:
    print("Yağ ve Gres değeri standartlara uygun değil")
  if NH4>150:
    print("Amonyum Azotu değeri standartlara uygun değil")
  if Cr>0.5:
    print("Krom değeri standartlara uygun değil")
  if Pb>2:
    print("Kurşun değeri standartlara uygun değil")
  if TCN>0.5:
    print("Koi değeri standartlara uygun değil")
  if pH<6 and pH>9:
    print("pH değeri standartlara uygun değil")

if x=="Taşıt Fabrikaları":
  koi=int(input("KOİ değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  NH4=int(input("Amonyum Azotu değeri giriniz:"))
  TCN=int(input("Toplam Siyanür değeri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  akm=int(input("AKM değeri giriniz:"))
  NO2=int(input("Nitrit Azotu değeri giriniz:"))
  SCN=float(input("Serbest Siyanür değeri giriniz:"))
  Cr=float(input("Krom değeri giriniz:"))
  Ni=int(input("Nikel değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Al=int(input("Alüminyum değeri giriniz:"))
  Pb=float(input("Kurşun değeri giriniz:"))
  Cu=float(input("Bakır değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  Hg=int(input("Civa değeri giriniz:"))
  Florür=int(input("Florür değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))

  if koi<=150 and YVG<=20 and NH4<=100 and TCN<=1 and TCr<=2 and ZSF<=10 and 6<pH<9 and akm<=80 and NO2<=5 and SCN<=0.05 and Cr<=0.05 and Ni<=1 and Cd<=0.05 and Fe<=3 and Al<=3 and Pb<=0.3 and Cu<=0.3 and Zn<=2 and Hg<=5 and Florür<=5 and renk<=280:
    print("Deşarj Standartlarına Uygun")
  else:
    print("Deşarj Standartlarına Uygun Değil Çünkü;")
  if koi>150:
    print("Koi değeri standartlara uygun değil")
  if YVG>20:
    print("YVG değeri standartlara uygun değil")
  if NH4>100:
    print("Amonyum Azotu değeri standartlara uygun değil")
  if TCN>1:
    print("Toplam Siyanür değeri standartlara uygun değil")
  if TCr>2:
    print("Toplam Krom değeri standartlara uygun değil")
  if ZSF>10:
    print("ZSF değeri standartlara uygun değil")
  if pH<6 and pH>9:
    print("pH değeri standartlara uygun değil")
  if akm>80:
    print("akm değeri standartlara uygun değil")
  if NO2>5:
    print("Nitrit Azotu değeri standartlara uygun değil")
  if SCN>0.05:
    print("Serbest Siyanür değeri standartlara uygun değil")
  if Cr>0.05:
    print("Krom değeri standartlara uygun değil")
  if Ni>1:
    print("Nikel değeri standartlara uygun değil")
  if Cd>0.05:
    print("Kadmiyum değeri standartlara uygun değil")
  if Fe>3:
    print("Demir değeri standartlara uygun değil")
  if Al>3:
    print("Alüminyum değeri standartlara uygun değil")
  if Pb>0.3:
    print("Kurşun değeri standartlara uygun değil")
  if Cu>0.3:
    print("Bakır değeri standartlara uygun değil")
  if Zn>2:
    print("Koi değeri standartlara uygun değil")
  if Hg>5:
    print("Civa değeri standartlara uygun değil")
  if Florür>5:
    print("Florür değeri standartlara uygun değil")
  if renk>280:
    print("renk değeri standartlara uygun değil")

if x=="Karışık Endüstriyel Atıksu":
  koi=int(input("KOİ değeri giriniz:"))
  akm=int(input("AKM değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  P=int(input("Toplam Fosfor değerleri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  Cr=float(input("krom değeri giriniz:"))
  Pb=int(input("Kurşun değeri giriniz:"))
  TCN=int(input("Toplam Siyanür değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Florür=int(input("Florür değeri giriniz:"))
  Cu=int(input("Bakır değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  Hg=float(input("Civa değeri giriniz:"))
  SO4=int(input("Sülfat değeri giriniz:"))
  TKN=int(input("Toplam kjeldahl Azotu değeri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))

  if koi<=250 and akm<=200 and YVG<=20 and P<=2 and TCr<=2 and Cr<=0.5 and Pb<=2 and TCN<=1 and Cd<=0.1 and Fe<=10 and Florür<=15 and Cu<=3 and Zn<=5 and Hg<=0.05 and SO4<=1500 and TKN<=20 and ZSF<=10 and renk<=280 and 6<=pH<=9:
    print("Deşarj Standartlarına Uygun")
  else:
    print("Deşarj Standartlarına Uygun Değil Çünkü;")
  if koi>250:
    print("Koi değeri standartlara uygun değil")
  if akm>200:
    print("akm değeri standartlara uygun değil")
  if YVG>20:
    print("YVG değeri standartlara uygun değil")
  if P>2:
    print("Toplam Fosfor değeri standartlara uygun değil")
  if TCr>2:
    print("Toplam Krom değeri standartlara uygun değil")
  if Cr<=0.05:
    print("Krom değeri standartlara uygun değil")
  if Pb>2:
    print("Kurşun değeri standartlara uygun değil")
  if TCN>1:
    print("Toplam Siyanür değeri standartlara uygun değil")
  if Cd>0.1:
    print("Kadmiyum değeri standartlara uygun değil")
  if Fe>10:
    print("Demir değeri standartlara uygun değil")
  if Florür>15:
    print("Florür değeri standartlara uygun değil")
  if Cu>3:
    print("Bakır değeri standartlara uygun değil")
  if Zn>5:
    print("Koi değeri standartlara uygun değil")
  if Hg>0.05:
    print("Civa değeri standartlara uygun değil")
  if SO4>1500:
    print("Sülfat değeri standartlara uygun değil")
  if TKN>20:
    print("Toplam kjeldahl Azotu değeri standartlara uygun değil")
  if ZSF>10:
    print("ZSF değeri standartlara uygun değil")
  if renk>280:
    print("renk değeri standartlara uygun değil")
  if pH<6 and pH>9:
    print("pH değeri standartlara uygun değil")

if x=="Endüstriyel nitelikli diğer atıksular":
  koi=int(input("KOİ değeri giriniz:"))
  YVG=int(input("Yağ ve Gres değerleri giriniz:"))
  ZSF=int(input("ZSF değeri giriniz:"))
  T=int(input("Sıcaklık değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  akm=int(input("AKM değeri giriniz:"))
  SO4=int(input("Sülfat değeri giriniz:"))
  TKN=int(input("Toplam kjeldahl Azotu değeri giriniz:"))
  P=int(input("Toplam Fosfor değerleri giriniz:"))
  TCr=int(input("Toplam Krom değeri giriniz:"))
  Cr=float(input("krom değeri giriniz:"))
  Pb=int(input("Kurşun değeri giriniz:"))
  TCN=int(input("Toplam Siyanür değeri giriniz:"))
  Cd=float(input("Kadmiyum değeri giriniz:"))
  Fe=int(input("Demir değeri giriniz:"))
  Florür=int(input("Florür değeri giriniz:"))
  Cu=int(input("Bakır değeri giriniz:"))
  Zn=int(input("Çinko değeri giriniz:"))
  renk=int(input("Renk değeri giriniz:"))
  Cl=int(input("Klor değeri giriniz:"))
  Sülfit=int(input("Sülfit değeri giriniz:"))
  MBAS=int(input("Yüzeyde aktif madde değeri giriniz:"))
  Sülfür=int(input("Sülfür değeri giriniz:"))
  Hg=float(input("Civa değeri giriniz:"))
  TPHC=int(input("Toplam petrol Hidrokarbonları değeri giriniz:"))
  Ni=int(input("Nikel değeri giriniz:"))

  if koi<=160 and YVG<=20 and ZSF<=5 and T<=35 and 6<=pH<=9 and akm<=150 and SO4<=2500 and TKN<=20 and P<=2 and TCr<=2 and Cr<=0.5 and Pb<=2 and TCN<=1 and Cd<=0.1 and Fe<=10 and Florür<=15 and Cu<=3 and Zn<=5 and renk<=280 and Cl<=2000 and Sülfit<=1 and MBAS<=10 and Sülfür<=1 and Hg<=0.05 and TPHC<=5 and Ni<=1:
    print("Deşarj Standartlarına Uygun")
  else:
    print("Deşarj Standartlarına Uygun Değil Çünkü;")
  if koi>250:
    print("Koi değeri standartlara uygun değil")
  if YVG>20:
    print("YVG değeri standartlara uygun değil")
  if ZSF>10:
    print("ZSF değeri standartlara uygun değil")
  if T>35:
    print("Sıcaklık değeri standartlara uygun değil")
  if pH<6 and pH>9:
    print("pH değeri standartlara uygun değil")
  if akm>200:
    print("akm değeri standartlara uygun değil")
  if SO4>1500:
    print("Sülfat değeri standartlara uygun değil")
  if TKN>20:
    print("Toplam kjeldahl Azotu değeri standartlara uygun değil")
  if P>2:
    print("Toplam Fosfor değeri standartlara uygun değil")
  if TCr>2:
    print("Toplam Krom değeri standartlara uygun değil")
  if Cr<=0.05:
    print("Krom değeri standartlara uygun değil")
  if Pb>2:
    print("Kurşun değeri standartlara uygun değil")
  if TCN>1:
    print("Toplam Siyanür değeri standartlara uygun değil")
  if Cd<=0.1:
    print("Kadmiyum değeri standartlara uygun değil")
  if Fe>10:
    print("Demir değeri standartlara uygun değil")
  if Florür>15:
    print("Florür değeri standartlara uygun değil")
  if Cu>3:
    print("Bakır değeri standartlara uygun değil")
  if Zn>5:
    print("Koi değeri standartlara uygun değil")
  if renk>280:
    print("renk değeri standartlara uygun değil")
  if Cl>2000:
    print("Klorür değeri standartlara uygun değil")
  if Sülfit>1:
    print("Sülfit değeri standartlara uygun değil")
  if MBAS>10:
    print("Yüzeyde Aktif madde değeri standartlara uygun değil")
  if Sülfür>1:
    print("Sülfür değeri standartlara uygun değil")
  if Hg>0.05:
    print("Civa değeri standartlara uygun değil")
  if TPHC>5:
    print("Toplam Petrol Hidrokarbonları değeri standartlara uygun değil")
  if Ni>1:
    print("Nikel değeri standartlara uygun değil")

if x=="Evsel Nitelikli Atıksuların Alıcı Ortama Dejarj Standartları":
  AKM=int(input("AKM değeri giriniz:"))
  pH=int(input("pH değeri giriniz:"))
  KOİ=int(input("KOİ değeri giriniz:"))
  BOİ=int(input("BOİ değerini giriniz:"))

  if KOİ<=160 and 6<=pH<=9 and  BOİ<=50 and AKM<=60:
    print("Deşarj Standartlarına uygun")
  else:
   print("Deşarj Standartlarına uygun değil çünkü;")
  if KOİ>160:
   print("KOİ değeri standartlara uygun değil")
  if BOİ>50:
   print("BOİ değeri standartlara uygun değil")
  if pH<6 and pH>9:
   print("pH değeri standartlara uygun değil")
  if AKM>60:
   print("AKM değeri standartlara uygun değil")
